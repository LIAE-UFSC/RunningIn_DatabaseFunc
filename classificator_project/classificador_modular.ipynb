# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('dataset_balanceado_pronto.csv')
input_dim = 6
n_features = 6
output_dim = 2
num_epochs = 10000
learning_rate = 0.01
test_size = 0.3
random_state = 42

# %%
df.head()
# Out:
#    massFlow_1  massFlow_2  massFlow_3  massFlow_4  massFlow_5  massFlow_6  \
# 0    0.261122    0.261525    0.257016    0.263706    0.264042    0.258191
# 1    0.248733    0.251273    0.252975    0.249206    0.258848    0.253853
# 2    0.254494    0.252283    0.254897    0.259973    0.255765    0.256653
# 3    0.251353    0.254784    0.256152    0.252397    0.255100    0.257605
# 4    0.251210    0.246467    0.242903    0.247801    0.242971    0.249442
#
#    anomaly
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
feature_cols = [col for col in df.columns if col != "anomaly"]
X = df[feature_cols].values
y = df['anomaly'].values

# %%
scaler = StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= test_size, random_state= random_state)

X_train_reshaped = X_train.reshape(-1, n_features) 
X_test_reshaped = X_test.reshape(-1, n_features)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
class NeuralNetworkClassificationModel(nn.Module):
    def __init__(self,input_dim,output_dim):
        super(NeuralNetworkClassificationModel,self).__init__()
        self.input_layer    = nn.Linear(input_dim,128)
        self.hidden_layer1  = nn.Linear(128,64)
        self.output_layer   = nn.Linear(64,output_dim)
        self.relu = nn.ReLU()
    
    
    def forward(self,x):
        out =  self.relu(self.input_layer(x))
        out =  self.relu(self.hidden_layer1(out))
        out =  self.output_layer(out)
        return out

# %%
# input_dim = 4 because we have 4 inputs namely sepal_length,sepal_width,petal_length,petal_width
# output_dim = 3 because we have namely 3 categories setosa,versicolor and virginica
input_dim  = input_dim
output_dim = output_dim
model = NeuralNetworkClassificationModel(input_dim,output_dim)

# %%
# creating our optimizer and loss function object
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)

# %%
def train_network(model,optimizer,criterion,X_train,y_train,X_test,y_test,num_epochs,train_losses,test_losses):
    for epoch in range(num_epochs):
        #clear out the gradients from the last step loss.backward()
        optimizer.zero_grad()
        
        #forward feed
        output_train = model(X_train)

        #calculate the loss
        loss_train = criterion(output_train, y_train)
        
        #backward propagation: calculate gradients
        loss_train.backward()

        #update the weights
        optimizer.step()
        
        output_test = model(X_test)
        loss_test = criterion(output_test,y_test)

        train_losses[epoch] = loss_train.item()
        test_losses[epoch] = loss_test.item()

        if (epoch + 1) % 50 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss_train.item():.4f}, Test Loss: {loss_test.item():.4f}")

# %%
train_losses = np.zeros(num_epochs)
test_losses  = np.zeros(num_epochs)
print(X_train.shape)  # Deve ser (n_amostras, 1)
print(X_train[:10])  # Exibe as primeiras 10 amostras
# Out:
# torch.Size([137, 6])
# tensor([[0.2527, 0.2538, 0.2540, 0.2514, 0.2548, 0.2562],
#         [0.2415, 0.2447, 0.2434, 0.2476, 0.2474, 0.2385],
#         [0.2529, 0.2566, 0.2464, 0.2527, 0.2538, 0.2540],
#         [0.2546, 0.2477, 0.2509, 0.2521, 0.2580, 0.2574],
#         [0.2576, 0.2562, 0.2606, 0.2543, 0.2590, 0.2538],
#         [0.2545, 0.2522, 0.2526, 0.2602, 0.2524, 0.2456],
#         [0.2605, 0.2617, 0.2638, 0.2599, 0.2549, 0.2541],
#         [0.2472, 0.2474, 0.2538, 0.2475, 0.2457, 0.2455],
#         [0.2452, 0.2382, 0.2424, 0.2395, 0.2445, 0.2418],
#         [0.2536, 0.2542, 0.2603, 0.2605, 0.2622, 0.2576]])

# %%
train_losses = np.zeros(num_epochs)
test_losses  = np.zeros(num_epochs)

print(X_train.shape)  # Deve ser (n_amostras, 1)
# Out:
# torch.Size([137, 6])

# %%
train_network(model,optimizer,criterion,X_train,y_train,X_test,y_test,num_epochs,train_losses,test_losses)
# Out:
# Epoch 50/10000, Train Loss: 0.6929, Test Loss: 0.6928
# Epoch 100/10000, Train Loss: 0.6718, Test Loss: 0.6354
# Epoch 150/10000, Train Loss: 0.5904, Test Loss: 0.4844
# Epoch 200/10000, Train Loss: 0.5704, Test Loss: 0.4483
# Epoch 250/10000, Train Loss: 0.5649, Test Loss: 0.4438
# Epoch 300/10000, Train Loss: 0.5568, Test Loss: 0.4262
# Epoch 350/10000, Train Loss: 0.5514, Test Loss: 0.4218
# Epoch 400/10000, Train Loss: 0.5533, Test Loss: 0.4167
# Epoch 450/10000, Train Loss: 0.5407, Test Loss: 0.4110
# Epoch 500/10000, Train Loss: 0.5385, Test Loss: 0.4138
# Epoch 550/10000, Train Loss: 0.5347, Test Loss: 0.4127
# Epoch 600/10000, Train Loss: 0.5276, Test Loss: 0.4041
# Epoch 650/10000, Train Loss: 0.5148, Test Loss: 0.4007
# Epoch 700/10000, Train Loss: 0.5068, Test Loss: 0.3973
# Epoch 750/10000, Train Loss: 0.5064, Test Loss: 0.4009
# Epoch 800/10000, Train Loss: 0.4961, Test Loss: 0.3889
# Epoch 850/10000, Train Loss: 0.4881, Test Loss: 0.3885
# Epoch 900/10000, Train Loss: 0.4790, Test Loss: 0.3850
# Epoch 950/10000, Train Loss: 0.4832, Test Loss: 0.3793
# Epoch 1000/10000, Train Loss: 0.4838, Test Loss: 0.4123
# Epoch 1050/10000, Train Loss: 0.4623, Test Loss: 0.3829
# Epoch 1100/10000, Train Loss: 0.4568, Test Loss: 0.3906
# Epoch 1150/10000, Train Loss: 0.4690, Test Loss: 0.3951
# Epoch 1200/10000, Train Loss: 0.4616, Test Loss: 0.3813
# Epoch 1250/10000, Train Loss: 0.4456, Test Loss: 0.3786
# Epoch 1300/10000, Train Loss: 0.4446, Test Loss: 0.3948
# Epoch 1350/10000, Train Loss: 0.4445, Test Loss: 0.3776
# Epoch 1400/10000, Train Loss: 0.4363, Test Loss: 0.3836
# Epoch 1450/10000, Train Loss: 0.4384, Test Loss: 0.3977
# Epoch 1500/10000, Train Loss: 0.4645, Test Loss: 0.4349
# Epoch 1550/10000, Train Loss: 0.4359, Test Loss: 0.3831
# Epoch 1600/10000, Train Loss: 0.4291, Test Loss: 0.3972
# Epoch 1650/10000, Train Loss: 0.4303, Test Loss: 0.3895
# Epoch 1700/10000, Train Loss: 0.4716, Test Loss: 0.4031
# Epoch 1750/10000, Train Loss: 0.4226, Test Loss: 0.3942
# Epoch 1800/10000, Train Loss: 0.4247, Test Loss: 0.3909
# Epoch 1850/10000, Train Loss: 0.4505, Test Loss: 0.4307
# Epoch 1900/10000, Train Loss: 0.4190, Test Loss: 0.3925
# Epoch 1950/10000, Train Loss: 0.4166, Test Loss: 0.3865
# Epoch 2000/10000, Train Loss: 0.4205, Test Loss: 0.3925
# Epoch 2050/10000, Train Loss: 0.4442, Test Loss: 0.4105
# Epoch 2100/10000, Train Loss: 0.4169, Test Loss: 0.3902
# Epoch 2150/10000, Train Loss: 0.4133, Test Loss: 0.3927
# Epoch 2200/10000, Train Loss: 0.4128, Test Loss: 0.4010
# Epoch 2250/10000, Train Loss: 0.4116, Test Loss: 0.3977
# Epoch 2300/10000, Train Loss: 0.4097, Test Loss: 0.4104
# Epoch 2350/10000, Train Loss: 0.4176, Test Loss: 0.4246
# Epoch 2400/10000, Train Loss: 0.4211, Test Loss: 0.4343
# Epoch 2450/10000, Train Loss: 0.4117, Test Loss: 0.4253
# Epoch 2500/10000, Train Loss: 0.4078, Test Loss: 0.3992
# Epoch 2550/10000, Train Loss: 0.4308, Test Loss: 0.4410
# Epoch 2600/10000, Train Loss: 0.4094, Test Loss: 0.3851
# Epoch 2650/10000, Train Loss: 0.4254, Test Loss: 0.4564
# Epoch 2700/10000, Train Loss: 0.4113, Test Loss: 0.4112
# Epoch 2750/10000, Train Loss: 0.4044, Test Loss: 0.4066
# Epoch 2800/10000, Train Loss: 0.4067, Test Loss: 0.4260
# Epoch 2850/10000, Train Loss: 0.4066, Test Loss: 0.4128
# Epoch 2900/10000, Train Loss: 0.4030, Test Loss: 0.4137
# Epoch 2950/10000, Train Loss: 0.4242, Test Loss: 0.4233
# Epoch 3000/10000, Train Loss: 0.4097, Test Loss: 0.4377
# Epoch 3050/10000, Train Loss: 0.4015, Test Loss: 0.4225
# Epoch 3100/10000, Train Loss: 0.3998, Test Loss: 0.4197
# Epoch 3150/10000, Train Loss: 0.4173, Test Loss: 0.4351
# Epoch 3200/10000, Train Loss: 0.3982, Test Loss: 0.4318
# Epoch 3250/10000, Train Loss: 0.4404, Test Loss: 0.4954
# Epoch 3300/10000, Train Loss: 0.3972, Test Loss: 0.4238
# Epoch 3350/10000, Train Loss: 0.3998, Test Loss: 0.4375
# Epoch 3400/10000, Train Loss: 0.4688, Test Loss: 0.5125
# Epoch 3450/10000, Train Loss: 0.3926, Test Loss: 0.4239
# Epoch 3500/10000, Train Loss: 0.3927, Test Loss: 0.4215
# Epoch 3550/10000, Train Loss: 0.4001, Test Loss: 0.4287
# Epoch 3600/10000, Train Loss: 0.4066, Test Loss: 0.4262
# Epoch 3650/10000, Train Loss: 0.3934, Test Loss: 0.4361
# Epoch 3700/10000, Train Loss: 0.3990, Test Loss: 0.4381
# Epoch 3750/10000, Train Loss: 0.3853, Test Loss: 0.4304
# Epoch 3800/10000, Train Loss: 0.3945, Test Loss: 0.4407
# Epoch 3850/10000, Train Loss: 0.4017, Test Loss: 0.4624
# Epoch 3900/10000, Train Loss: 0.3803, Test Loss: 0.4405
# Epoch 3950/10000, Train Loss: 0.3937, Test Loss: 0.4619
# Epoch 4000/10000, Train Loss: 0.3770, Test Loss: 0.4467
# Epoch 4050/10000, Train Loss: 0.3763, Test Loss: 0.4362
# Epoch 4100/10000, Train Loss: 0.3736, Test Loss: 0.4404
# Epoch 4150/10000, Train Loss: 0.3952, Test Loss: 0.4304
# Epoch 4200/10000, Train Loss: 0.3831, Test Loss: 0.4345
# Epoch 4250/10000, Train Loss: 0.3705, Test Loss: 0.4173
# Epoch 4300/10000, Train Loss: 0.3761, Test Loss: 0.4033
# Epoch 4350/10000, Train Loss: 0.3702, Test Loss: 0.4136
# Epoch 4400/10000, Train Loss: 0.3732, Test Loss: 0.3990
# Epoch 4450/10000, Train Loss: 0.3732, Test Loss: 0.4111
# Epoch 4500/10000, Train Loss: 0.3651, Test Loss: 0.4254
# Epoch 4550/10000, Train Loss: 0.3674, Test Loss: 0.4218
# Epoch 4600/10000, Train Loss: 0.3668, Test Loss: 0.4135
# Epoch 4650/10000, Train Loss: 0.3898, Test Loss: 0.4660
# Epoch 4700/10000, Train Loss: 0.3612, Test Loss: 0.4121
# Epoch 4750/10000, Train Loss: 0.3998, Test Loss: 0.4420
# Epoch 4800/10000, Train Loss: 0.3671, Test Loss: 0.4320
# Epoch 4850/10000, Train Loss: 0.3577, Test Loss: 0.4299
# Epoch 4900/10000, Train Loss: 0.3557, Test Loss: 0.4287
# Epoch 4950/10000, Train Loss: 0.3973, Test Loss: 0.4783
# Epoch 5000/10000, Train Loss: 0.3593, Test Loss: 0.4452
# Epoch 5050/10000, Train Loss: 0.3510, Test Loss: 0.4101
# Epoch 5100/10000, Train Loss: 0.3795, Test Loss: 0.4703
# Epoch 5150/10000, Train Loss: 0.3780, Test Loss: 0.4562
# Epoch 5200/10000, Train Loss: 0.3701, Test Loss: 0.4481
# Epoch 5250/10000, Train Loss: 0.3433, Test Loss: 0.4244
# Epoch 5300/10000, Train Loss: 0.3480, Test Loss: 0.4354
# Epoch 5350/10000, Train Loss: 0.4198, Test Loss: 0.5480
# Epoch 5400/10000, Train Loss: 0.3389, Test Loss: 0.4362
# Epoch 5450/10000, Train Loss: 0.3404, Test Loss: 0.4359
# Epoch 5500/10000, Train Loss: 0.3844, Test Loss: 0.4878
# Epoch 5550/10000, Train Loss: 0.3710, Test Loss: 0.4748
# Epoch 5600/10000, Train Loss: 0.3348, Test Loss: 0.4376
# Epoch 5650/10000, Train Loss: 0.3328, Test Loss: 0.4370
# Epoch 5700/10000, Train Loss: 0.3905, Test Loss: 0.4995
# Epoch 5750/10000, Train Loss: 0.3289, Test Loss: 0.4382
# Epoch 5800/10000, Train Loss: 0.6001, Test Loss: 0.7017
# Epoch 5850/10000, Train Loss: 0.3278, Test Loss: 0.4271
# Epoch 5900/10000, Train Loss: 0.3253, Test Loss: 0.4397
# Epoch 5950/10000, Train Loss: 0.4021, Test Loss: 0.4218
# Epoch 6000/10000, Train Loss: 0.4899, Test Loss: 0.4955
# Epoch 6050/10000, Train Loss: 0.4639, Test Loss: 0.4334
# Epoch 6100/10000, Train Loss: 0.4519, Test Loss: 0.4190
# Epoch 6150/10000, Train Loss: 0.4448, Test Loss: 0.4137
# Epoch 6200/10000, Train Loss: 0.4393, Test Loss: 0.4117
# Epoch 6250/10000, Train Loss: 0.4358, Test Loss: 0.4103
# Epoch 6300/10000, Train Loss: 0.4307, Test Loss: 0.4144
# Epoch 6350/10000, Train Loss: 0.4252, Test Loss: 0.4135
# Epoch 6400/10000, Train Loss: 0.4212, Test Loss: 0.4090
# Epoch 6450/10000, Train Loss: 0.4205, Test Loss: 0.4138
# Epoch 6500/10000, Train Loss: 0.4199, Test Loss: 0.4435
# Epoch 6550/10000, Train Loss: 0.4106, Test Loss: 0.4104
# Epoch 6600/10000, Train Loss: 0.4073, Test Loss: 0.4162
# Epoch 6650/10000, Train Loss: 0.4051, Test Loss: 0.4173
# Epoch 6700/10000, Train Loss: 0.3995, Test Loss: 0.4155
# Epoch 6750/10000, Train Loss: 0.4056, Test Loss: 0.4323
# Epoch 6800/10000, Train Loss: 0.3995, Test Loss: 0.4240
# Epoch 6850/10000, Train Loss: 0.4223, Test Loss: 0.4228
# Epoch 6900/10000, Train Loss: 0.3911, Test Loss: 0.4167
# Epoch 6950/10000, Train Loss: 0.3995, Test Loss: 0.4162
# Epoch 7000/10000, Train Loss: 0.3904, Test Loss: 0.4242
# Epoch 7050/10000, Train Loss: 0.3839, Test Loss: 0.4168
# Epoch 7100/10000, Train Loss: 0.4643, Test Loss: 0.5605
# Epoch 7150/10000, Train Loss: 0.3784, Test Loss: 0.4143
# Epoch 7200/10000, Train Loss: 0.3751, Test Loss: 0.4174
# Epoch 7250/10000, Train Loss: 0.6231, Test Loss: 0.6718
# Epoch 7300/10000, Train Loss: 0.4109, Test Loss: 0.4560
# Epoch 7350/10000, Train Loss: 0.4072, Test Loss: 0.4529
# Epoch 7400/10000, Train Loss: 0.4051, Test Loss: 0.4529
# Epoch 7450/10000, Train Loss: 0.4040, Test Loss: 0.4471
# Epoch 7500/10000, Train Loss: 0.4088, Test Loss: 0.4682
# Epoch 7550/10000, Train Loss: 0.4054, Test Loss: 0.4480
# Epoch 7600/10000, Train Loss: 0.3985, Test Loss: 0.4560
# Epoch 7650/10000, Train Loss: 0.4084, Test Loss: 0.4470
# Epoch 7700/10000, Train Loss: 0.3962, Test Loss: 0.4404
# Epoch 7750/10000, Train Loss: 0.3958, Test Loss: 0.4418
# Epoch 7800/10000, Train Loss: 0.3964, Test Loss: 0.4535
# Epoch 7850/10000, Train Loss: 0.3983, Test Loss: 0.4335
# Epoch 7900/10000, Train Loss: 0.3922, Test Loss: 0.4462
# Epoch 7950/10000, Train Loss: 0.3974, Test Loss: 0.4491
# Epoch 8000/10000, Train Loss: 0.3901, Test Loss: 0.4459
# Epoch 8050/10000, Train Loss: 0.3885, Test Loss: 0.4475
# Epoch 8100/10000, Train Loss: 0.3888, Test Loss: 0.4439
# Epoch 8150/10000, Train Loss: 0.3971, Test Loss: 0.4459
# Epoch 8200/10000, Train Loss: 0.3831, Test Loss: 0.4386
# Epoch 8250/10000, Train Loss: 0.3937, Test Loss: 0.4758
# Epoch 8300/10000, Train Loss: 0.3848, Test Loss: 0.4518
# Epoch 8350/10000, Train Loss: 0.3887, Test Loss: 0.4435
# Epoch 8400/10000, Train Loss: 0.3845, Test Loss: 0.4338
# Epoch 8450/10000, Train Loss: 0.3821, Test Loss: 0.4434
# Epoch 8500/10000, Train Loss: 0.3798, Test Loss: 0.4381
# Epoch 8550/10000, Train Loss: 0.3765, Test Loss: 0.4425
# Epoch 8600/10000, Train Loss: 0.4120, Test Loss: 0.4722
# Epoch 8650/10000, Train Loss: 0.3784, Test Loss: 0.4392
# Epoch 8700/10000, Train Loss: 0.3737, Test Loss: 0.4566
# Epoch 8750/10000, Train Loss: 0.3720, Test Loss: 0.4474
# Epoch 8800/10000, Train Loss: 0.3906, Test Loss: 0.4771
# Epoch 8850/10000, Train Loss: 0.3679, Test Loss: 0.4421
# Epoch 8900/10000, Train Loss: 0.3699, Test Loss: 0.4509
# Epoch 8950/10000, Train Loss: 0.3665, Test Loss: 0.4391
# Epoch 9000/10000, Train Loss: 0.3695, Test Loss: 0.4471
# Epoch 9050/10000, Train Loss: 0.3745, Test Loss: 0.4394
# Epoch 9100/10000, Train Loss: 0.3986, Test Loss: 0.3885
# Epoch 9150/10000, Train Loss: 0.3957, Test Loss: 0.3865
# Epoch 9200/10000, Train Loss: 0.3948, Test Loss: 0.3836
# Epoch 9250/10000, Train Loss: 0.3958, Test Loss: 0.3922
# Epoch 9300/10000, Train Loss: 0.3955, Test Loss: 0.3845
# Epoch 9350/10000, Train Loss: 0.3932, Test Loss: 0.3799
# Epoch 9400/10000, Train Loss: 0.3946, Test Loss: 0.3761
# Epoch 9450/10000, Train Loss: 0.3927, Test Loss: 0.3807
# Epoch 9500/10000, Train Loss: 0.3976, Test Loss: 0.3652
# Epoch 9550/10000, Train Loss: 0.3928, Test Loss: 0.3803
# Epoch 9600/10000, Train Loss: 0.3916, Test Loss: 0.3791
# Epoch 9650/10000, Train Loss: 0.4151, Test Loss: 0.4072
# Epoch 9700/10000, Train Loss: 0.3913, Test Loss: 0.3756
# Epoch 9750/10000, Train Loss: 0.3911, Test Loss: 0.3765
# Epoch 9800/10000, Train Loss: 0.3955, Test Loss: 0.3818
# Epoch 9850/10000, Train Loss: 0.3904, Test Loss: 0.3775
# Epoch 9900/10000, Train Loss: 0.3918, Test Loss: 0.3698
# Epoch 9950/10000, Train Loss: 0.4331, Test Loss: 0.4164
# Epoch 10000/10000, Train Loss: 0.3902, Test Loss: 0.3773

# %%
plt.figure(figsize=(10,10))
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
predictions_train = []
predictions_test =  []
with torch.no_grad():
    predictions_train = model(X_train)
    predictions_test = model(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

def get_accuracy_multiclass(pred_arr, original_arr, label="Dataset"):
    if len(pred_arr) != len(original_arr):
        return False

    pred_arr = pred_arr.numpy()
    original_arr = original_arr.numpy()

    final_pred = []

    for i in range(len(pred_arr)):
        final_pred.append(np.argmax(pred_arr[i]))

    final_pred = np.array(final_pred)

    count = 0
    for i in range(len(original_arr)):
        if final_pred[i] == original_arr[i]:
            count += 1

    acc = count / len(final_pred)

    print(f"\n{'='*10} {label.upper()} METRICS {'='*10}")
    print("\n> Confusion Matrix:")
    print(confusion_matrix(original_arr, final_pred))
    
    print("\n> Classification Report:")
    print(classification_report(original_arr, final_pred, digits=4))

    print(f"> Accuracy: {acc:.4f}")

    return acc

# %%
train_acc = get_accuracy_multiclass(predictions_train, y_train, label="Training Set")
test_acc  = get_accuracy_multiclass(predictions_test, y_test, label="Test Set")
# Out:
# ========== TRAINING SET METRICS ==========
#
# > Confusion Matrix:
# [[60  8]
#  [17 52]]
#
# > Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7792    0.8824    0.8276        68
#            1     0.8667    0.7536    0.8062        69
#
#     accuracy                         0.8175       137
#    macro avg     0.8229    0.8180    0.8169       137
# weighted avg     0.8233    0.8175    0.8168       137
#
# > Accuracy: 0.8175
#
# ========== TEST SET METRICS ==========
#
# > Confusion Matrix:
# [[26  4]
#  [ 6 23]]
#
# > Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8125    0.8667    0.8387        30
#            1     0.8519    0.7931    0.8214        29
#
#     accuracy                         0.8305        59
#    macro avg     0.8322    0.8299    0.8301        59
# weighted avg     0.8318    0.8305    0.8302        59
#
# > Accuracy: 0.8305

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Aqui, você já tem o cálculo das acurácias
print(f"Training Accuracy: {round(train_acc*100,3)}")
print(f"Test Accuracy: {round(test_acc*100,3)}")

# Aplicando PCA para reduzir as dimensões para 1 (pois temos 1 feature)
pca = PCA(n_components=1)

# Reduzindo as dimensões dos dados totais (treinamento + teste)
X_total = torch.cat((X_train, X_test), dim=0)  # Concatenando os dados de treino e teste
X_total_pca = pca.fit_transform(X_total)  # Aplicando o PCA no conjunto total

# Plotando os resultados de PCA
plt.figure(figsize=(8, 6))

# Plotando os dados totais
plt.scatter(X_total_pca[:, 0], np.zeros_like(X_total_pca[:, 0]), c=torch.cat((y_train, y_test)), cmap='viridis', alpha=0.5)

# Adicionando títulos e legendas
plt.title('PCA of Total Data (1D)')
plt.xlabel('PCA Component 1')
plt.ylabel('Zero Line (for visualization)')
plt.colorbar(label='Class')

plt.show()

# PCA(n_components=1): Reduz os dados para apenas 1 componente principal.

# torch.cat((X_train, X_test), dim=0): Combina os dados de treino e teste em um único array/tensor (X_total).

# fit_transform(X_total): Calcula o PCA e transforma os dados para o novo espaço 1D.

# Eixo X: Valores da componente principal 1 (X_total_pca[:, 0]).

# Eixo Y: Uma linha de zeros (np.zeros_like), apenas para visualização (já que os dados são 1D).

# Cores: Definidas pelas classes (y_train e y_test concatenadas), usando o colormap viridis.

# Distribuição 1D: Mostra como as amostras se distribuem ao longo da única componente principal.

# Separação de Classes:

# Se as classes (cores) estiverem bem separadas ao longo do eixo X, a componente 1 é discriminativa.

# Se estiverem misturadas, a feature original não separa bem as classes.

# PCA(n_components=1) cria uma nova componente que é uma combinação linear de time e massFlow.

# A fórmula seria algo como:
# PC1 = a * time + b * massFlow
# (onde a e b são os "loadings" calculados pelo PCA)
# Out:
# Training Accuracy: 81.752
# Test Accuracy: 83.051

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA

# # 1. Preparar os dados
# X = df1[['time', 'massFlow']].values  # Features (time e massFlow)
# y = df1['anomaly'].values             # Rótulos (anomaly)

# # 2. Aplicar PCA para reduzir para 2 componentes (para visualização)
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X)

# # 3. Criar um mapa de cores para as classes (assumindo que 'n_amac' é a classe normal)
# classes = np.unique(y)
# colors = {'n_amac': 'blue', 'n_sab': 'red', 'amac': 'green'}  # Defina cores para cada classe

# # 4. Plotar os resultados
# plt.figure(figsize=(10, 6))

# # Plotar cada classe separadamente para legenda clara
# for cls in classes:
#     mask = (y == cls)
#     plt.scatter(X_pca[mask, 0], X_pca[mask, 1], 
#                c=colors.get(cls, 'gray'), 
#                label=cls, 
#                alpha=0.7)

# # Adicionar títulos e legendas
# plt.title('PCA of Time vs. MassFlow (2D)')
# plt.xlabel('Principal Component 1 (PC1)')
# plt.ylabel('Principal Component 2 (PC2)')
# plt.legend()
# plt.grid(True)

# # Mostrar a variância explicada por cada componente
# explained_var = pca.explained_variance_ratio_
# print(f"Variância explicada: PC1 = {explained_var[0]:.2%}, PC2 = {explained_var[1]:.2%}")

# plt.show()


# # X: Extrai as colunas 'time' e 'massFlow' do DataFrame df1 e converte para um array NumPy

# # y: Extrai a coluna 'anomaly' (que contém as classes/labels) como um array NumPy

# # Eixo X: Primeiro componente principal (PC1)

# # Eixo Y: Segundo componente principal (PC2)

# # Cores: Classes diferentes (n_amac, n_sab, amac)

# # Pontos: Cada ponto representa uma observação no novo espaço 2D
